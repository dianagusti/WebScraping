# %% [markdown]
# <a href="https://colab.research.google.com/github/dianagusti/WebScraping/blob/master/WebScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scraping Detik.com

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url = 'https://www.detik.com/terpopuler'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

list_content = soup.select('article')

list_content
# Out:
# [<article class="list-content__item">
#  <div class="media media--left media--image-radius block-link">
#  <div class="media__image">
#  <!-- <span class="media__label bg-blue font-xs">LABEL</span> -->
#  <a class="media__link" href="https://news.detik.com/internasional/d-7732988/presiden-korsel-yoon-suk-yeol-ditangkap" onclick='_pt(this, "newsfeed", "Presiden Korsel Yoon Suk Yeol Ditangkap!", "artikel newsfeed")'>
#  <span class="ratiobox ratiobox--4-3 lqd">
#  <img alt="Presiden Korsel Yoon Suk Yeol Ditangkap!" class="" src="https://awsimages.detik.net.id/community/media/visual/2024/12/12/presiden-korsel-yoon-suk-yeol_43.jpeg?w=220&amp;q=90" title="Presiden Korsel Yoon Suk Yeol Ditangkap!"> </img></span>
#  </a>
#  </div>
#  <div class="media__text">
#  <h3 class="media__title">
# ...

# %%
results = []
for item in list_content:
  data = dict()

  #data collection
  data['title'] = item.select_one('.media__title').text
  data['url'] = item.select_one('.media__image a').get('href')
  results.append(data)

pd.DataFrame(results)
# Out:
#                                                 title  \
# 0        \nPresiden Korsel Yoon Suk Yeol Ditangkap!\n
# 1          \nSaat Jairo Riedewald Main di Indonesia\n
# 2   \nCerita Pria Jalan Kaki 250 Ribu Langkah dala...
# 3   \nPresiden Korsel Ditangkap, Terancam Hukuman ...
# 4   \nCerita di Balik Perjumpaan Tak Sengaja Prabo...
# 5   \nDramatisnya Penangkapan Presiden Korsel, Pen...
# 6   \nSosok Penyampai Pesan Prabowo ke Megawati Te...
# 7   \nPuspen TNI: Brigjen (Purn) Hendrawan Ostevan...
# 8   \nKata Mereka yang Pernah Coba Obat Setelan, D...
# 9   \nMotor Bonceng 3 Ternyata Sempat Naik Tol Lay...
# 10  \nMark Zuckerberg Umumkan PHK Besar-besaran di...
# 11  \nEfek Opsen Pajak, Harga Mobil Naik Jadi Segi...
# 12  \nBung Towel Jelaskan Postingan STY Cocoknya J...
# 13  \nDaftar HP Xiaomi, Redmi, dan Poco yang Bakal...
# 14  \nSalah Kaprah Mitsubishi Pajero & Toyota Fort...
# 15  \nPrabowo Larang Keras Bangun Rumah di Lahan S...
# ...
